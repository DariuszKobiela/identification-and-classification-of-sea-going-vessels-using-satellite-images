# %% [markdown]
# GITHUB FOR TUTORIAL: https://github.com/WongKinYiu/yolov7
#
# YOTUBE TUTORIAL: https://www.youtube.com/watch?v=_fXABNYlZhY
#
# YOUTUBE PRZYGOTOWANIE DANYCH: https://www.youtube.com/watch?v=-QWxJ0j9EY8&t=60s

# %% [markdown]
# ![image.png](attachment:5c92f334-7324-4310-95a0-1a0457dd14e3.png)

# %%
import os

# %%
if not os.path.isdir("TheCodingBug"):
    os.makedirs("TheCodingBug")

# %%
# %cd TheCodingBug/
# Out:
# [WinError 2] Nie można odnaleźć określonego pliku: 'TheCodingBug/'
# C:\Users\user\Documents\identification-and-classification-of-sea-going-vessels-using-satellite-images\notebooks\TheCodingBug

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...

# %% [markdown]
# # Train YOLOv7 Custom Model

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %cd yolov7
# Out:
# C:\Users\user\Documents\identification-and-classification-of-sea-going-vessels-using-satellite-images\notebooks\TheCodingBug\yolov7

# %%
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7x.pt
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !python train.py --device 0 --batch-size 16 --epochs 5 --img 640 640 --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7x-custom.yaml --weights yolov7x.pt --name yolov7x-custom
# Out:
# Traceback (most recent call last):
#   File "C:\Users\user\Documents\identification-and-classification-of-sea-going-vessels-using-satellite-images\notebooks\TheCodingBug\yolov7\train.py", line 595, in <module>
#     device = select_device(opt.device, batch_size=opt.batch_size)
#   File "C:\Users\user\Documents\identification-and-classification-of-sea-going-vessels-using-satellite-images\notebooks\TheCodingBug\yolov7\utils\torch_utils.py", line 71, in select_device
#     assert torch.cuda.is_available(), f'CUDA unavailable, invalid device {device} requested'  # check availability
# AssertionError: CUDA unavailable, invalid device 0 requested

# %%
# !python train.py --batch-size 16 --epochs 5 --img 640 640 --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7x-custom.yaml --weights yolov7x.pt --name yolov7x-custom
# Out:
# wandb: Install Weights & Biases for YOLOR logging with 'pip install wandb' (recommended)
# YOLOR  v0.1-121-g2fdc7f1 torch 1.12.1+cpu CPU
#
# Namespace(weights='yolov7x.pt', cfg='cfg/training/yolov7x-custom.yaml', data='data/custom_data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=5, batch_size=16, img_size=[640, 640], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='yolov7x-custom', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs\\train\\yolov7x-custom2', total_batch_size=16)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...
